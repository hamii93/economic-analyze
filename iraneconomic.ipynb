# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = "/home/hamed/Dataanalyze_train/economic-analyze/IRAN -WORLDBANK.xlsx"

# %%
df = pd.read_excel(data, sheet_name='Data')

# %%
df.head()
# Out:
#                                       Indicator Name     Indicator Code  1960  \
# 0  Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5   NaN
# 1           Battle-related deaths (number of people)        VC.BTL.DETH   NaN
# 2          Voice and Accountability: Percentile Rank         VA.PER.RNK   NaN
# 3  Transport services (% of commercial service ex...  TX.VAL.TRAN.ZS.WT   NaN
# 4  Computer, communications and other services (%...  TX.VAL.OTHR.ZS.WT   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  ...      2013      2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.756053  0.569035
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.164319  5.911330
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
#
#        2015       2016       2017       2018       2019        2020  \
# ...

# %%
df1 = df.to_csv("iraneconomic.csv")

# %%
df =pd.read_csv("iraneconomic.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                     Indicator Name  \
# 0           0  Intentional homicides, female (per 100,000 fem...
# 1           1           Battle-related deaths (number of people)
# 2           2          Voice and Accountability: Percentile Rank
# 3           3  Transport services (% of commercial service ex...
# 4           4  Computer, communications and other services (%...
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  1966  ...      2013  \
# 0  VC.IHR.PSRC.FE.P5   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.756053
# 1        VC.BTL.DETH   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 2         VA.PER.RNK   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.164319
# 3  TX.VAL.TRAN.ZS.WT   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 4  TX.VAL.OTHR.ZS.WT   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
#
#        2014      2015       2016       2017       2018       2019        2020  \
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                                     Indicator Name  \
# 1472        1472  Short-term debt (% of exports of goods, servic...
# 1473        1473  External debt stocks, private nonguaranteed (P...
# 1474        1474     External debt stocks, total (DOD, current US$)
# 1475        1475  Net ODA provided to the least developed countr...
# 1476        1476  Net bilateral aid flows from DAC donors, Swede...
#
#          Indicator Code  1960  1961          1962           1963  1964  1965  \
# 1472  DT.DOD.DSTC.XP.ZS   NaN   NaN           NaN            NaN   NaN   NaN
# 1473     DT.DOD.DPNG.CD   NaN   NaN           NaN            NaN   NaN   NaN
# 1474     DT.DOD.DECT.CD   NaN   NaN           NaN            NaN   NaN   NaN
# 1475  DC.ODA.TLDC.GN.ZS   NaN   NaN           NaN            NaN   NaN   NaN
# 1476     DC.DAC.SWEL.CD   NaN   NaN  39999.999106  119999.997318   NaN   NaN
#
#       1966  ...          2013          2014          2015          2016  \
# ...

# %%
df.isna().sum
# Out:
# <bound method DataFrame.sum of       Unnamed: 0  Indicator Name  Indicator Code  1960  1961   1962   1963  \
# 0          False           False           False  True  True   True   True
# 1          False           False           False  True  True   True   True
# 2          False           False           False  True  True   True   True
# 3          False           False           False  True  True   True   True
# 4          False           False           False  True  True   True   True
# ...          ...             ...             ...   ...   ...    ...    ...
# 1472       False           False           False  True  True   True   True
# 1473       False           False           False  True  True   True   True
# 1474       False           False           False  True  True   True   True
# 1475       False           False           False  True  True   True   True
# 1476       False           False           False  True  True  False  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1477 entries, 0 to 1476
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1477 non-null   int64
#  1   Indicator Name  1477 non-null   object
#  2   Indicator Code  1477 non-null   object
#  3   1960            247 non-null    float64
#  4   1961            286 non-null    float64
#  5   1962            292 non-null    float64
#  6   1963            308 non-null    float64
#  7   1964            320 non-null    float64
#  8   1965            328 non-null    float64
#  9   1966            331 non-null    float64
#  10  1967            327 non-null    float64
#  11  1968            329 non-null    float64
#  12  1969            316 non-null    float64
#  13  1970            348 non-null    float64
#  14  1971            431 non-null    float64
#  15  1972            458 non-null    float64
#  16  1973            462 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.columns['Unamed: 0']
#
# File ~/miniconda3/envs/pyanalyze/lib/python3.13/site-packages/pandas/core/indexes/base.py:5428, in Index.__getitem__(self, key)
#    5419         if len(key) == 0 and len(key) != len(self):
#    5420             warnings.warn(
#    5421                 "Using a boolean indexer with length 0 on an Index with "
#    5422                 "length greater than 0 is deprecated and will raise in a "
#    (...)   5425                 stacklevel=find_stack_level(),
#    5426             )
# -> 5428 result = getitem(key)
#    5429 # Because we ruled out integer above, we always get an arraylike here
#    5430 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
